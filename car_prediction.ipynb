# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
# ...

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df['current year'] = 2021

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner  current year
# ...

# %%
df['Vehicle Age'] = df['current year'] - df['year']

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner  current year  Vehicle Age
# ...

# %%
plt.figure(figsize=(12,6) , dpi = 100)
df['name'].value_counts()[:12].plot(kind='barh'  , color = ['#15244C','#FFFF49','#292734','#EF2920','#CD202D','#ECC5F2',
               '#294A75','#D4480B','#242317','#FD512F','#158EA6','#E82865'])
count = 0
for i in df['name'].value_counts()[:12]:
    #plt.text(count-0.33,i+1.5,i )
    plt.text(i+0.2 ,count-0.1,i , fontsize = 12)
    count+=1
plt.show()

# %%
plt.figure(figsize=(12,6) , dpi = 100)
df['Vehicle Age'].value_counts()[:12].plot(kind='bar'  , color = ['#15685C','#FFFF49','#292734','#EF2920','#CD202D','#ECC5F2',
               '#294A75','#D4480B','#FFFF49','#FD512F','#158EA6','#E82865'])
count = 0
for i in df['name'].value_counts()[:12]:
    plt.text(count-0.1,count + 120 ,i )
    #plt.text(i+0.2 ,count-0.1,i , fontsize = 12)
    count+=1

plt.title('NO OF CAR WITH AGE OF USE', fontsize = 15,color='blue' )
plt.ylabel('NAME OF CAR ' ,fontsize = 15)
plt.xlabel('AGE OF CARS' , fontsize = 15)
plt.show()

# %%
df.drop(['year'] , axis = 1 , inplace = True)

# %%
df.drop(['current year'] , axis = 1 , inplace = True)

# %%
df
# Out:
#                                      name  selling_price  km_driven    fuel  \
# 0                           Maruti 800 AC          60000      70000  Petrol
# 1                Maruti Wagon R LXI Minor         135000      50000  Petrol
# 2                    Hyundai Verna 1.6 SX         600000     100000  Diesel
# 3                  Datsun RediGO T Option         250000      46000  Petrol
# 4                   Honda Amaze VX i-DTEC         450000     141000  Diesel
# ...                                   ...            ...        ...     ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)         409999      80000  Diesel
# 4336           Hyundai i20 Magna 1.4 CRDi         409999      80000  Diesel
# 4337                  Maruti 800 AC BSIII         110000      83000  Petrol
# 4338     Hyundai Creta 1.6 CRDi SX Option         865000      90000  Diesel
# 4339                     Renault KWID RXT         225000      40000  Petrol
#
#      seller_type transmission         owner  Vehicle Age
# ...

# %%
df['selling_price'].hist(ec = 'gold' , bins = 50 )

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'Vehicle Age'],
#       dtype='object')

# %%
car_dekho = df[['selling_price', 'km_driven', 'fuel', 'seller_type',
       'transmission', 'owner', 'Vehicle Age']]

# %%
print(car_dekho['fuel'].unique())
print(car_dekho['transmission'].unique())
print(car_dekho['owner'].unique())
print(car_dekho['seller_type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']
# ['Manual' 'Automatic']
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']
# ['Individual' 'Dealer' 'Trustmark Dealer']

# %%
car_dekho
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner  \
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 2            600000     100000  Diesel  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 4            450000     141000  Diesel  Individual       Manual  Second Owner
# ...             ...        ...     ...         ...          ...           ...
# 4335         409999      80000  Diesel  Individual       Manual  Second Owner
# 4336         409999      80000  Diesel  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4338         865000      90000  Diesel  Individual       Manual   First Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
#       Vehicle Age
# ...

# %%
car_dekho = pd.get_dummies(car_dekho , drop_first=True)

# %%
car_dekho
# Out:
#       selling_price  km_driven  Vehicle Age  fuel_Diesel  fuel_Electric  \
# 0             60000      70000           14            0              0
# 1            135000      50000           14            0              0
# 2            600000     100000            9            1              0
# 3            250000      46000            4            0              0
# 4            450000     141000            7            1              0
# ...             ...        ...          ...          ...            ...
# 4335         409999      80000            7            1              0
# 4336         409999      80000            7            1              0
# 4337         110000      83000           12            0              0
# 4338         865000      90000            5            1              0
# 4339         225000      40000            5            0              0
#
#       fuel_LPG  fuel_Petrol  seller_type_Individual  \
# ...

# %%
corr_car = car_dekho.corr()

# %%
plt.figure(figsize=(20,20), dpi=200)
sns.heatmap(corr_car , annot= True , cmap= 'RdYlBu')

# %%
top_feature = corr_car.index

# %%
plt.figure(figsize=(20,20), dpi=200)
sns.heatmap(car_dekho[top_feature].corr() , annot= True , cmap= 'RdYlBu')

# %%
car_dekho.head()
# Out:
#    selling_price  km_driven  Vehicle Age  fuel_Diesel  fuel_Electric  \
# 0          60000      70000           14            0              0
# 1         135000      50000           14            0              0
# 2         600000     100000            9            1              0
# 3         250000      46000            4            0              0
# 4         450000     141000            7            1              0
#
#    fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0         0            1                       1
# 1         0            1                       1
# 2         0            0                       1
# 3         0            1                       1
# 4         0            0                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  \
# 0                             0                    1
# 1                             0                    1
# 2                             0                    1
# ...

# %%
x = car_dekho.iloc[: , 1:]

# %%
y = car_dekho.iloc[:,0]

# %%
x.shape
# Out:
# (4340, 13)

# %%
y.shape
# Out:
# (4340,)

# %%
x.head()
# Out:
#    km_driven  Vehicle Age  fuel_Diesel  fuel_Electric  fuel_LPG  fuel_Petrol  \
# 0      70000           14            0              0         0            1
# 1      50000           14            0              0         0            1
# 2     100000            9            1              0         0            0
# 3      46000            4            0              0         0            1
# 4     141000            7            1              0         0            0
#
#    seller_type_Individual  seller_type_Trustmark Dealer  transmission_Manual  \
# 0                       1                             0                    1
# 1                       1                             0                    1
# 2                       1                             0                    1
# 3                       1                             0                    1
# 4                       1                             0                    1
#
# ...

# %%
y.head()
# Out:
# 0     60000
# 1    135000
# 2    600000
# 3    250000
# 4    450000
# Name: selling_price, dtype: int64

# %% [markdown]
# # ` Now Model analysis with machine learning algorithms`

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([2.40272824e-01, 2.50310050e-01, 1.30310130e-01, 3.37252942e-05,
#        2.54268387e-05, 2.30473257e-04, 4.86983570e-02, 9.06783118e-03,
#        2.92828459e-01, 7.97360481e-04, 2.25243569e-02, 5.03383840e-04,
#        4.39762135e-03])

# %%
feature_important = pd.Series(model.feature_importances_ , index = x.columns)

# %%
feature_important
# Out:
# km_driven                       0.240273
# Vehicle Age                     0.250310
# fuel_Diesel                     0.130310
# fuel_Electric                   0.000034
# fuel_LPG                        0.000025
# fuel_Petrol                     0.000230
# seller_type_Individual          0.048698
# seller_type_Trustmark Dealer    0.009068
# transmission_Manual             0.292828
# owner_Fourth & Above Owner      0.000797
# owner_Second Owner              0.022524
# owner_Test Drive Car            0.000503
# owner_Third Owner               0.004398
# dtype: float64

# %%
feature_important.nlargest(5).plot(kind='barh')

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size = 0.2 , random_state = 42)

# %%
x_train.shape
# Out:
# (3472, 13)

# %%
x_test.shape
# Out:
# (868, 13)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_R = RandomForestRegressor()

# %%
n_estimators=[int(x) for x in np.linspace(start = 100 , stop = 5000 , num = 50)]
max_depth= [ int(x) for x in np.linspace(5,30 , num = 6)]
min_samples_split= [2,5,10,15,100]
min_samples_leaf= [1,2,5,10]
max_features= ['auto', 'sqrt']

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_R = RandomForestRegressor()

# %%
random_regresor = RandomizedSearchCV(estimator=rf_R , param_distributions= random_grid , n_jobs= 1 , verbose= 2 ,n_iter= 10 , cv=5 , random_state= 42 , scoring='neg_mean_squared_error')

# %%
random_regresor
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100, 1200,
#                                                          1300, 1400, 1500, 1600,
#                                                          1700, 1800, 1900, 2000,
#                                                          2100, 2200, 2300, 2400,
# ...

# %%
random_regresor.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=2100, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=2100, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=  10.4s
# [CV] n_estimators=2100, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.3s remaining:    0.0s
# [CV]  n_estimators=2100, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=  10.5s
# [CV] n_estimators=2100, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=20
# [CV]  n_estimators=2100, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=20, total=  10.4s
# [CV] n_estimators=2100, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=20
# ...

# %%
prediction = random_regresor.predict(x_test)

# %%
prediction[:5]
# Out:
# array([ 199171.67220143,  477074.64563358,  149533.96903266,
#         485082.83127973, 1541516.06327437])

# %%
y_test[:5]
# Out:
# 3978    165000
# 1448    250000
# 2664    120000
# 17      450000
# 1634    730000
# Name: selling_price, dtype: int64

# %%
sns.distplot(y_test)

# %%
sns.distplot(prediction)

# %%
sns.distplot(y_test - prediction)

# %%
y_test-prediction
# Out:
# 3978    -34171.672201
# 1448   -227074.645634
# 2664    -29533.969033
# 17      -35082.831280
# 1634   -811516.063274
#             ...
# 3468      7706.142985
# 3164   -219420.611955
# 416    -146943.762061
# 1616     11679.357611
# 2480     51151.372170
# Name: selling_price, Length: 868, dtype: float64

# %%
import pickle
file = open('random_forest_car_deko.pkl' , 'wb')
pickle.dump(rf_R , file)
